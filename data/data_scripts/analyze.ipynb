# %%
import os
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/matthewcasertano/Library/Mobile Documents/com~apple~CloudDocs/final_project/data/data_scripts

# %%
import pandas as pd

# Load the CSV file
file_path = '../final_data_for_sql/equipment.csv'  # Ensure the file path is correct
df = pd.read_csv(file_path)


unique_manufacturers = df['manufacturer'].dropna().unique()
print("Unique Manufacturers:")
for manufacturer in unique_manufacturers:
    print(manufacturer)
# Out:
# Unique Manufacturers:
# Fairchild
# Sierra Nevada Corporation
# Lockheed Martin
# Rockwell International
# Northrop Grumman
# Boeing
# Beechcraft
# De Havilland Canada
# McDonnell Douglas & Boeing
# Learjet
# Gulfstream
# CASA
# Bell & Boeing
# McDonnell Douglas
# General Dynamics
# Sikorsky
# AgustaWestland
# General Atomics
# Composite Engineering
# Bombardier
# AeroVironment
# DZYNE Technologies
# Raytheon
# Cessna
# Cirrus
# Raytheon & Beechcraft
# Boeing & Saab
# Bell
# Pilatus
# Alenia Aeronautica
# Mil Moscow Helicopter Plant
# Airbus Eurocopter
# Prioria Robotics
# MMIST
# FLIR
# Airbus
# Bell Boeing
# Kaman
# Boeing Insitu
# Skydio
# McDonnell Douglas, Northrop Grumman & Boeing
# BAE Systems
# Various
# Elbit Systems
# L3Harris
# Textron
# Navistar
# Oshkosh Defense
# Force Protection
# AM General
# GM Defense
# Polaris
# Hagglunds
# Caterpillar
# Aardvark Clear Mine Ltd
# DCD Protected Mobility
# Hydrema

# %%
# Load the CSV file
df = pd.read_csv('../final_data_for_sql/users.csv')

# Select and print the first two columns
for index, row in df.iloc[:, :2].iterrows():
        print(f"{row.iloc[0]}: {row.iloc[1]}")
# Out:
#                           name                        contact_email
# 0                    Fairchild                fairchild@example.com
# 1    Sierra Nevada Corporation  sierranevadacorporation@example.com
# 2              Lockheed Martin           lockheedmartin@example.com
# 3       Rockwell International    rockwellinternational@example.com
# 4             Northrop Grumman          northropgrumman@example.com
# ..                         ...                                  ...
# 142                Mexico Navy              customer143@example.com
# 143           Mexico Air Force              customer144@example.com
# 144             Mexico Marines              customer145@example.com
# 145         Mexico Coast Guard              customer146@example.com
# 146         Mexico Space Force              customer147@example.com
#
# [147 rows x 2 columns]
