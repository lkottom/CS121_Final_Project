# %%
import os
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/matthewcasertano/Library/Mobile Documents/com~apple~CloudDocs/final_project/data/data_scripts

# %%
import pandas as pd

# Load the CSV file
file_path = '../final_data_for_sql/equipment.csv'  # Ensure the file path is correct
df = pd.read_csv(file_path)


unique_manufacturers = df['manufacturer'].dropna().unique()
print("Unique Manufacturers:")
for manufacturer in unique_manufacturers:
    print(manufacturer)
# Out:
# Unique Manufacturers:
# Fairchild
# Sierra Nevada Corporation
# Lockheed Martin
# Rockwell International
# Northrop Grumman
# Boeing
# Beechcraft
# De Havilland Canada
# McDonnell Douglas & Boeing
# Learjet
# Gulfstream
# CASA
# Bell & Boeing
# McDonnell Douglas
# General Dynamics
# Sikorsky
# AgustaWestland
# General Atomics
# Composite Engineering
# Bombardier
# AeroVironment
# DZYNE Technologies
# Raytheon
# Cessna
# Cirrus
# Raytheon & Beechcraft
# Boeing & Saab
# Bell
# Pilatus
# Alenia Aeronautica
# Mil Moscow Helicopter Plant
# Airbus Eurocopter
# Prioria Robotics
# MMIST
# FLIR
# Airbus
# Bell Boeing
# Kaman
# Boeing Insitu
# Skydio
# McDonnell Douglas, Northrop Grumman & Boeing
# BAE Systems
# Various
# Elbit Systems
# L3Harris
# Textron
# Navistar
# Oshkosh Defense
# Force Protection
# AM General
# GM Defense
# Polaris
# Hagglunds
# Caterpillar
# Aardvark Clear Mine Ltd
# DCD Protected Mobility
# Hydrema

# %%
# Load the CSV file
df = pd.read_csv('../final_data_for_sql/users.csv')

# Select and print the first two columns
for index, row in df.iloc[:, :2].iterrows():
        print(f"{row.iloc[0]}: {row.iloc[1]}")
# Out:
# Fairchild: fairchild@example.com
# Sierra Nevada Corporation: sierranevadacorporation@example.com
# Lockheed Martin: lockheedmartin@example.com
# Rockwell International: rockwellinternational@example.com
# Northrop Grumman: northropgrumman@example.com
# Boeing: boeing@example.com
# Beechcraft: beechcraft@example.com
# De Havilland Canada: dehavillandcanada@example.com
# McDonnell Douglas & Boeing: mcdonnelldouglas&boeing@example.com
# Learjet: learjet@example.com
# Gulfstream: gulfstream@example.com
# CASA: casa@example.com
# Bell & Boeing: bell&boeing@example.com
# McDonnell Douglas: mcdonnelldouglas@example.com
# General Dynamics: generaldynamics@example.com
# Sikorsky: sikorsky@example.com
# AgustaWestland: agustawestland@example.com
# General Atomics: generalatomics@example.com
# Composite Engineering: compositeengineering@example.com
# Bombardier: bombardier@example.com
# AeroVironment: aerovironment@example.com
# DZYNE Technologies: dzynetechnologies@example.com
# Raytheon: raytheon@example.com
# Cessna: cessna@example.com
# Cirrus: cirrus@example.com
# Raytheon & Beechcraft: raytheon&beechcraft@example.com
# Boeing & Saab: boeing&saab@example.com
# Bell: bell@example.com
# Pilatus: pilatus@example.com
# Alenia Aeronautica: aleniaaeronautica@example.com
# Mil Moscow Helicopter Plant: milmoscowhelicopterplant@example.com
# Airbus Eurocopter: airbuseurocopter@example.com
# Prioria Robotics: prioriarobotics@example.com
# MMIST: mmist@example.com
# FLIR: flir@example.com
# Airbus: airbus@example.com
# Bell Boeing: bellboeing@example.com
# Kaman: kaman@example.com
# Boeing Insitu: boeinginsitu@example.com
# Skydio: skydio@example.com
# McDonnell Douglas, Northrop Grumman & Boeing: mcdonnelldouglas,northropgrumman&boeing@example.com
# BAE Systems: baesystems@example.com
# Various: various@example.com
# Elbit Systems: elbitsystems@example.com
# L3Harris: l3harris@example.com
# Textron: textron@example.com
# Navistar: navistar@example.com
# Oshkosh Defense: oshkoshdefense@example.com
# Force Protection: forceprotection@example.com
# AM General: amgeneral@example.com
# GM Defense: gmdefense@example.com
# Polaris: polaris@example.com
# Hagglunds: hagglunds@example.com
# Caterpillar: caterpillar@example.com
# Aardvark Clear Mine Ltd: aardvarkclearmineltd@example.com
# DCD Protected Mobility: dcdprotectedmobility@example.com
# Hydrema: hydrema@example.com
# U.S. Army: customer58@example.com
# U.S. Navy: customer59@example.com
# U.S. Air Force: customer60@example.com
# U.S. Marines: customer61@example.com
# U.S. Coast Guard: customer62@example.com
# U.S. Space Force: customer63@example.com
# U.K. Army: customer64@example.com
# U.K. Navy: customer65@example.com
# U.K. Air Force: customer66@example.com
# U.K. Marines: customer67@example.com
# U.K. Coast Guard: customer68@example.com
# U.K. Space Force: customer69@example.com
# Germany Army: customer70@example.com
# Germany Navy: customer71@example.com
# Germany Air Force: customer72@example.com
# Germany Marines: customer73@example.com
# Germany Coast Guard: customer74@example.com
# Germany Space Force: customer75@example.com
# France Army: customer76@example.com
# France Navy: customer77@example.com
# France Air Force: customer78@example.com
# France Marines: customer79@example.com
# France Coast Guard: customer80@example.com
# France Space Force: customer81@example.com
# Canada Army: customer82@example.com
# Canada Navy: customer83@example.com
# Canada Air Force: customer84@example.com
# Canada Marines: customer85@example.com
# Canada Coast Guard: customer86@example.com
# Canada Space Force: customer87@example.com
# Japan Army: customer88@example.com
# Japan Navy: customer89@example.com
# Japan Air Force: customer90@example.com
# Japan Marines: customer91@example.com
# Japan Coast Guard: customer92@example.com
# Japan Space Force: customer93@example.com
# Australia Army: customer94@example.com
# Australia Navy: customer95@example.com
# Australia Air Force: customer96@example.com
# Australia Marines: customer97@example.com
# Australia Coast Guard: customer98@example.com
# Australia Space Force: customer99@example.com
# Israel Army: customer100@example.com
# Israel Navy: customer101@example.com
# Israel Air Force: customer102@example.com
# Israel Marines: customer103@example.com
# Israel Coast Guard: customer104@example.com
# Israel Space Force: customer105@example.com
# Brazil Army: customer106@example.com
# Brazil Navy: customer107@example.com
# Brazil Air Force: customer108@example.com
# Brazil Marines: customer109@example.com
# Brazil Coast Guard: customer110@example.com
# Brazil Space Force: customer111@example.com
# Russia Army: customer112@example.com
# Russia Navy: customer113@example.com
# Russia Air Force: customer114@example.com
# Russia Marines: customer115@example.com
# Russia Coast Guard: customer116@example.com
# Russia Space Force: customer117@example.com
# China Army: customer118@example.com
# China Navy: customer119@example.com
# China Air Force: customer120@example.com
# China Marines: customer121@example.com
# China Coast Guard: customer122@example.com
# China Space Force: customer123@example.com
# Egypt Army: customer124@example.com
# Egypt Navy: customer125@example.com
# Egypt Air Force: customer126@example.com
# Egypt Marines: customer127@example.com
# Egypt Coast Guard: customer128@example.com
# Egypt Space Force: customer129@example.com
# Italy Army: customer130@example.com
# Italy Navy: customer131@example.com
# Italy Air Force: customer132@example.com
# Italy Marines: customer133@example.com
# Italy Coast Guard: customer134@example.com
# Italy Space Force: customer135@example.com
# Spain Army: customer136@example.com
# Spain Navy: customer137@example.com
# Spain Air Force: customer138@example.com
# Spain Marines: customer139@example.com
# Spain Coast Guard: customer140@example.com
# Spain Space Force: customer141@example.com
# Mexico Army: customer142@example.com
# Mexico Navy: customer143@example.com
# Mexico Air Force: customer144@example.com
# Mexico Marines: customer145@example.com
# Mexico Coast Guard: customer146@example.com
# Mexico Space Force: customer147@example.com
